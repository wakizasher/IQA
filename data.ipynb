# %%
import pandas as pd
import numpy as np

# %%
df_bellis_perennis = pd.read_csv(r"C:\Users\Nikita\Projects\ExtractImages\data\observations-545799.csv", low_memory=False)
df_leucanthemum_vulgare = pd.read_csv(r"C:\Users\Nikita\Projects\ExtractImages\data\observations-545980.csv", low_memory=False)
df_matricaria_chamomilla = pd.read_csv(r"C:\Users\Nikita\Projects\ExtractImages\data\observations-546007.csv", low_memory=False)

# %%
df_plantae = pd.concat([df_bellis_perennis, df_leucanthemum_vulgare, df_matricaria_chamomilla], ignore_index=True)

# %%
df_plantae.shape
# Out:
# (114467, 40)

# %%
df_plantae.columns
# Out:
# Index(['id', 'uuid', 'observed_on_string', 'observed_on', 'time_observed_at',
#        'time_zone', 'user_id', 'user_login', 'user_name', 'created_at',
#        'updated_at', 'quality_grade', 'license', 'url', 'image_url',
#        'sound_url', 'tag_list', 'description', 'num_identification_agreements',
#        'num_identification_disagreements', 'captive_cultivated',
#        'oauth_application_id', 'place_guess', 'latitude', 'longitude',
#        'positional_accuracy', 'private_place_guess', 'private_latitude',
#        'private_longitude', 'public_positional_accuracy', 'geoprivacy',
#        'taxon_geoprivacy', 'coordinates_obscured', 'positioning_method',
#        'positioning_device', 'species_guess', 'scientific_name', 'common_name',
#        'iconic_taxon_name', 'taxon_id'],
#       dtype='object')

# %%
df_plantae["quality_grade"].unique()
# Out:
# array(['research', 'needs_id'], dtype=object)

# %%
df_plantae.head(20)
# Out:
#        id                                  uuid  \
# 0    5239  c63a2027-8df0-42e4-87bb-238998b14dab
# 1    6641  c76e9ad7-033b-437d-80c8-72b55c68d3f7
# 2   10645  67cf8895-6288-487e-9816-600eb00a5b70
# 3   13644  8bbd3665-dd02-4257-884f-b195b2445f53
# 4   14749  aeefc85f-c506-4dc8-afe6-bb48780135ab
# 5   37766  b640ab20-09fd-4566-b274-498fc1116293
# 6   46293  d57d0699-3129-4ee9-8eb5-3ea406a59d03
# 7   47308  6d171945-b260-40c6-801c-0ac561939c1e
# 8   47822  e0b646f4-fba6-4cc3-a4d2-1e7a418b5bbe
# 9   55783  2afe6397-909f-41a4-9131-b7485b806caa
# 10  55794  5330b898-1801-4cbe-a80a-a8ddcb6e5143
# 11  56190  a53be7a7-1c44-4bc0-b7f8-3b460887434a
# 12  57486  dcfce48d-2a50-4281-b2eb-9abfcac7010f
# 13  58501  1991e063-db03-4ad8-b6c6-fe593d2c0b92
# 14  58666  b3be02e3-c545-4c20-88a6-144d63e7b422
# 15  61936  0e3b8792-070b-4ea3-9a4b-4490b038004a
# 16  63439  90ebf07f-4b74-40cf-8dd6-858e016db5a8
# 17  67951  0165d903-c4b4-4537-914c-6156246650b4
# ...

# %%
df_plantae.drop(columns=['uuid', 'observed_on_string', 'user_login', 'user_name', 'updated_at', 'sound_url',
                              'tag_list', 'description', 'captive_cultivated', 'oauth_application_id', 'place_guess',
                              'positional_accuracy', 'private_place_guess', 'private_latitude', 'private_longitude',
                              'public_positional_accuracy', 'geoprivacy', 'taxon_geoprivacy', 'coordinates_obscured',
                              'positioning_method', 'positioning_device', 'species_guess', 'common_name', 'iconic_taxon_name'], axis=1, inplace=True)

# %%
df_plantae.shape
# Out:
# (114467, 16)

# %%
df_plantae.isna().sum()
# Out:
# id                                      0
# observed_on                             0
# time_observed_at                     1737
# time_zone                               1
# user_id                                 0
# created_at                              0
# quality_grade                           0
# license                             28979
# url                                     0
# image_url                               0
# num_identification_agreements           0
# num_identification_disagreements        0
# latitude                              176
# longitude                             176
# scientific_name                         0
# taxon_id                                0
# dtype: int64

# %%
df_plantae.loc[df_plantae['quality_grade'] == 'needs_id']
# Out:
#               id observed_on         time_observed_at       time_zone  \
# 32414   82011060  2021-06-07  2021-06-07 12:25:52 UTC        Pretoria
# 33406   84688188  2021-06-27  2021-06-27 12:46:12 UTC        Brussels
# 33409   84693076  2021-06-27  2021-06-27 13:32:23 UTC        Brussels
# 96364   82320120  2021-06-09  2021-06-09 15:23:00 UTC        Brussels
# 96937   83815343  2021-06-20  2021-06-20 17:26:38 UTC  St. Petersburg
# 97184   84652488  2021-06-23  2021-06-23 11:09:00 UTC     Kaliningrad
# 97640   86550364  2021-07-11  2021-07-11 12:56:30 UTC        Pretoria
# 112675  85435667  2021-06-26  2021-06-26 12:22:00 UTC     Kaliningrad
#
#         user_id               created_at quality_grade   license  \
# 32414   4546928  2021-06-07 12:26:00 UTC      needs_id       NaN
# 33406   2098287  2021-06-27 12:50:22 UTC      needs_id       NaN
# 33409   2817190  2021-06-27 13:32:55 UTC      needs_id  CC-BY-NC
# 96364   4145037  2021-06-09 17:57:20 UTC      needs_id  CC-BY-NC
# ...

# %%
df_plantae.drop(df_plantae.loc[df_plantae['quality_grade'] == 'needs_id'].index,inplace=True)

# %%
df_plantae.shape
# Out:
# (114459, 16)

# %%
(114467 - 114459)
# Out:
# 8

# %%
df_plantae.to_csv('plants.csv', index=False)
